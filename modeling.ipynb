# %%
import numpy as np
import pandas as pd
import seaborn as sns
import copy
from pathlib import Path
import warnings

import lightning.pytorch as pl
from lightning.pytorch.callbacks import EarlyStopping, LearningRateMonitor
from lightning.pytorch.loggers import TensorBoardLogger
import numpy as np
import pandas as pd
import psycopg
import torch

from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import MAE, SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import (
    optimize_hyperparameters,
)
import util_funcs as util

# %%
config = util.load_config("_config_.yaml")
sql_conn_str = f"postgresql://{config['sql_username']}:{config['sql_password']}@localhost:{config['sql_port']}/premier_league_data"
conn = psycopg.Connection.connect(conninfo=sql_conn_str)
conn.close()

# %%
with open("queries/team_data.sql", "r") as infile:
    team_sql = infile.read()

with open("queries/match_data.sql", "r") as infile:
    match_sql = infile.read()

with psycopg.Connection.connect(conninfo=sql_conn_str) as conn:
    team_df = pd.read_sql(team_sql, con=conn)
    match_df = pd.read_sql(match_sql, con=conn)
# Out:
# /tmp/ipykernel_11100/2211280633.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   team_df = pd.read_sql(team_sql, con=conn)
# /tmp/ipykernel_11100/2211280633.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   match_df = pd.read_sql(match_sql, con=conn)

# %%
team_df.head()
# Out:
#   season  rk            squad  mp   w   d   l  gf  ga   gd  pts  pts_per_mp  \
# 0  23/24   1  Manchester City  38  28   7   3  96  34  +62   91        2.39
# 1  23/24   2          Arsenal  38  28   5   5  91  29  +62   89        2.34
# 2  23/24   3        Liverpool  38  24  10   4  86  41  +45   82        2.16
# 3  23/24   4      Aston Villa  38  20   8  10  76  61  +15   68        1.79
# 4  23/24   5        Tottenham  38  20   6  12  74  61  +13   66        1.74
#
#      xg   xga   xgd  xgd_per_90 attendance      top_team_scorer  \
# 0  80.5  35.6  44.9        1.18      53012  Erling Haaland - 27
# 1  76.1  27.9  48.2        1.27      60236     Bukayo Saka - 16
# 2  87.8  45.7  42.0        1.11      55979   Mohamed Salah - 18
# 3  63.3  59.9   3.4        0.09      41858   Ollie Watkins - 19
# 4  68.2  63.4   4.8        0.13      61482   Son Heung-min - 17
#
#           goalkeeper                                 notes
# 0            Ederson  → Champions League via league finish
# 1         David Raya  → Champions League via league finish
# 2            Alisson  → Champions League via league finish
# 3  Emiliano Martínez  → Champions League via league finish
# 4  Guglielmo Vicario     → Europa League via league finish

# %%
match_df.head()
# Out:
#       season       team first_name last_name  match_date day_of_week  \
# 0  2024-2025  Liverpool    Mohamed     Salah  2024-08-17         Sat
# 1  2024-2025  Liverpool    Mohamed     Salah  2024-08-25         Sun
# 2  2024-2025  Liverpool    Mohamed     Salah  2024-09-01         Sun
# 3  2024-2025  Liverpool    Mohamed     Salah  2024-09-14         Sat
# 4  2024-2025  Liverpool    Mohamed     Salah  2024-09-21         Sat
#
#              comp        round venue match_result  ... passes_launch_pct  \
# 0  Premier League  Matchweek 1  Away        W 2–0  ...               NaN
# 1  Premier League  Matchweek 2  Home        W 2–0  ...               NaN
# 2  Premier League  Matchweek 3  Away        W 3–0  ...               NaN
# 3  Premier League  Matchweek 4  Home        L 0–1  ...               NaN
# 4  Premier League  Matchweek 5  Home        W 3–0  ...               NaN
#
#   passes_avglen goal_kicks_att goal_kicks_avglen goal_kicks_launch_pct  \
# 0           NaN            NaN               NaN                   NaN
# 1           NaN            NaN               NaN                   NaN
# 2           NaN            NaN               NaN                   NaN
# 3           NaN            NaN               NaN                   NaN
# 4           NaN            NaN               NaN                   NaN
#
#    crosses_opp  crosses_stp  crosses_stp_pct  sweeper_num_opa  sweeper_avgdist
# 0          NaN          NaN              NaN              NaN              NaN
# 1          NaN          NaN              NaN              NaN              NaN
# 2          NaN          NaN              NaN              NaN              NaN
# 3          NaN          NaN              NaN              NaN              NaN
# 4          NaN          NaN              NaN              NaN              NaN
#
# [5 rows x 65 columns]

# %%
match_df.season = match_df.season.apply(lambda x: x[2:4] + '/' + x[-2:])
match_df.head()
# Out:
#   season       team first_name last_name  match_date day_of_week  \
# 0  24/25  Liverpool    Mohamed     Salah  2024-08-17         Sat
# 1  24/25  Liverpool    Mohamed     Salah  2024-08-25         Sun
# 2  24/25  Liverpool    Mohamed     Salah  2024-09-01         Sun
# 3  24/25  Liverpool    Mohamed     Salah  2024-09-14         Sat
# 4  24/25  Liverpool    Mohamed     Salah  2024-09-21         Sat
#
#              comp        round venue match_result  ... passes_launch_pct  \
# 0  Premier League  Matchweek 1  Away        W 2–0  ...               NaN
# 1  Premier League  Matchweek 2  Home        W 2–0  ...               NaN
# 2  Premier League  Matchweek 3  Away        W 3–0  ...               NaN
# 3  Premier League  Matchweek 4  Home        L 0–1  ...               NaN
# 4  Premier League  Matchweek 5  Home        W 3–0  ...               NaN
#
#   passes_avglen goal_kicks_att goal_kicks_avglen goal_kicks_launch_pct  \
# 0           NaN            NaN               NaN                   NaN
# 1           NaN            NaN               NaN                   NaN
# 2           NaN            NaN               NaN                   NaN
# 3           NaN            NaN               NaN                   NaN
# 4           NaN            NaN               NaN                   NaN
#
#    crosses_opp  crosses_stp  crosses_stp_pct  sweeper_num_opa  sweeper_avgdist
# 0          NaN          NaN              NaN              NaN              NaN
# 1          NaN          NaN              NaN              NaN              NaN
# 2          NaN          NaN              NaN              NaN              NaN
# 3          NaN          NaN              NaN              NaN              NaN
# 4          NaN          NaN              NaN              NaN              NaN
#
# [5 rows x 65 columns]

# %%
team_df.head()
# Out:
#   season  rk            squad  mp   w   d   l  gf  ga   gd  pts  pts_per_mp  \
# 0  23/24   1  Manchester City  38  28   7   3  96  34  +62   91        2.39
# 1  23/24   2          Arsenal  38  28   5   5  91  29  +62   89        2.34
# 2  23/24   3        Liverpool  38  24  10   4  86  41  +45   82        2.16
# 3  23/24   4      Aston Villa  38  20   8  10  76  61  +15   68        1.79
# 4  23/24   5        Tottenham  38  20   6  12  74  61  +13   66        1.74
#
#      xg   xga   xgd  xgd_per_90 attendance      top_team_scorer  \
# 0  80.5  35.6  44.9        1.18      53012  Erling Haaland - 27
# 1  76.1  27.9  48.2        1.27      60236     Bukayo Saka - 16
# 2  87.8  45.7  42.0        1.11      55979   Mohamed Salah - 18
# 3  63.3  59.9   3.4        0.09      41858   Ollie Watkins - 19
# 4  68.2  63.4   4.8        0.13      61482   Son Heung-min - 17
#
#           goalkeeper                                 notes
# 0            Ederson  → Champions League via league finish
# 1         David Raya  → Champions League via league finish
# 2            Alisson  → Champions League via league finish
# 3  Emiliano Martínez  → Champions League via league finish
# 4  Guglielmo Vicario     → Europa League via league finish

# %%
team_df.shape
# Out:
# (160, 20)

# %%
team_df["xg_per_game"] = team_df["xg"] / team_df["mp"]
team_df["xga_per_game"] = team_df["xga"] / team_df["mp"]

# %%
team_df.head()
# Out:
#   season  rk            squad  mp   w   d   l  gf  ga   gd  ...    xg   xga  \
# 0  23/24   1  Manchester City  38  28   7   3  96  34  +62  ...  80.5  35.6
# 1  23/24   2          Arsenal  38  28   5   5  91  29  +62  ...  76.1  27.9
# 2  23/24   3        Liverpool  38  24  10   4  86  41  +45  ...  87.8  45.7
# 3  23/24   4      Aston Villa  38  20   8  10  76  61  +15  ...  63.3  59.9
# 4  23/24   5        Tottenham  38  20   6  12  74  61  +13  ...  68.2  63.4
#
#     xgd  xgd_per_90  attendance      top_team_scorer         goalkeeper  \
# 0  44.9        1.18       53012  Erling Haaland - 27            Ederson
# 1  48.2        1.27       60236     Bukayo Saka - 16         David Raya
# 2  42.0        1.11       55979   Mohamed Salah - 18            Alisson
# 3   3.4        0.09       41858   Ollie Watkins - 19  Emiliano Martínez
# 4   4.8        0.13       61482   Son Heung-min - 17  Guglielmo Vicario
#
#                                   notes xg_per_game xga_per_game
# 0  → Champions League via league finish    2.118421     0.936842
# 1  → Champions League via league finish    2.002632     0.734211
# 2  → Champions League via league finish    2.310526     1.202632
# 3  → Champions League via league finish    1.665789     1.576316
# 4     → Europa League via league finish    1.794737     1.668421
#
# [5 rows x 22 columns]

# %%
team_df["match_season"] = team_df["season"].apply(lambda x: f"{int(x[:2])+1}/{int(x[-2:])+1}")

# %%
team_df.sample(5)
# Out:
#     season  rk            squad  mp   w   d   l  gf  ga   gd  ...   xga   xgd  \
# 16   23/24  17  Nott'ham Forest  38   9   9  20  49  67  -18  ...  53.2  -3.3
# 76   20/21  17          Burnley  38  10   9  19  33  55  -22  ...  54.7 -15.4
# 60   20/21   1  Manchester City  38  27   5   6  83  32  +51  ...  30.2  38.0
# 38   22/23  19     Leeds United  38   7  10  21  48  78  -30  ...  67.1 -19.8
# 111  18/19  12   Crystal Palace  38  14   7  17  51  53   -2  ...  50.1  -2.5
#
#      xgd_per_90  attendance        top_team_scorer      goalkeeper  \
# 16        -0.09       29386        Chris Wood - 14     Matt Turner
# 76        -0.40         178        Chris Wood - 12       Nick Pope
# 60         1.00         526    İlkay Gündoğan - 13         Ederson
# 38        -0.52       36566           Rodrigo - 13   Illan Meslier
# 111       -0.07       25455  Luka Milivojević - 12  Vicente Guaita
#
#                                     notes xg_per_game xga_per_game  \
# 16                    4-point deduction 2    1.313158     1.400000
# 76                                   None    1.034211     1.439474
# 60   → Champions League via league finish    1.794737     0.794737
# 38                              Relegated    1.244737     1.765789
# 111                                  None    1.252632     1.318421
#
#     match_season
# 16         24/25
# 76         21/22
# 60         21/22
# 38         23/24
# 111        19/20
#
# [5 rows x 23 columns]

# %%
match_df.shape
# Out:
# (88430, 65)

# %%
match_df = match_df.merge(team_df[["match_season", "squad", "xg_per_game", "xga_per_game"]], left_on=["season", "opponent"], right_on=["match_season", "squad"], how="inner").drop(columns=["squad_y", "match_season"])
match_df = match_df.rename(mapper={"xg_per_game": "opponent_prev_xg_per_game", "xga_per_game": "opponent_prev_xga_per_game"}, axis=1)
match_df.head()
# Out:
#   season       team first_name last_name  match_date day_of_week  \
# 0  24/25  Liverpool    Mohamed     Salah  2024-08-25         Sun
# 1  24/25  Liverpool    Mohamed     Salah  2024-09-01         Sun
# 2  24/25  Liverpool    Mohamed     Salah  2024-09-14         Sat
# 3  24/25  Liverpool    Mohamed     Salah  2024-09-21         Sat
# 4  24/25  Liverpool    Mohamed     Salah  2024-09-28         Sat
#
#              comp        round venue match_result  ... goal_kicks_att  \
# 0  Premier League  Matchweek 2  Home        W 2–0  ...            NaN
# 1  Premier League  Matchweek 3  Away        W 3–0  ...            NaN
# 2  Premier League  Matchweek 4  Home        L 0–1  ...            NaN
# 3  Premier League  Matchweek 5  Home        W 3–0  ...            NaN
# 4  Premier League  Matchweek 6  Away        W 2–1  ...            NaN
#
#   goal_kicks_avglen goal_kicks_launch_pct crosses_opp crosses_stp  \
# 0               NaN                   NaN         NaN         NaN
# 1               NaN                   NaN         NaN         NaN
# 2               NaN                   NaN         NaN         NaN
# 3               NaN                   NaN         NaN         NaN
# 4               NaN                   NaN         NaN         NaN
#
#    crosses_stp_pct  sweeper_num_opa  sweeper_avgdist  \
# 0              NaN              NaN              NaN
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN
#
#    opponent_prev_xg_per_game  opponent_prev_xga_per_game
# 0                   1.531579                    1.473684
# 1                   1.486842                    1.813158
# 2                   1.313158                    1.400000
# 3                   1.471053                    1.528947
# 4                   1.228947                    1.781579
#
# [5 rows x 67 columns]

# %%
match_df.shape
# Out:
# (66037, 67)

# %%
match_df.loc[match_df["opponent_prev_xg_per_game"].isna()][["season", "team", "opponent"]]
# Out:
# Empty DataFrame
# Columns: [season, team, opponent]
# Index: []

# %%
match_df["clean_sheet"] = match_df.apply(lambda x: x["match_result"][-1] == '0' if x["venue"] == "Away" else (x["match_result"][2] == '0' if x["venue"] == "Home" else np.nan), axis=1)

# %%
match_df[["season", "team", "first_name", "last_name", "venue", "match_result", "clean_sheet"]].head()
# Out:
#   season       team first_name last_name venue match_result  clean_sheet
# 0  24/25  Liverpool    Mohamed     Salah  Home        W 2–0        False
# 1  24/25  Liverpool    Mohamed     Salah  Away        W 3–0         True
# 2  24/25  Liverpool    Mohamed     Salah  Home        L 0–1         True
# 3  24/25  Liverpool    Mohamed     Salah  Home        W 3–0        False
# 4  24/25  Liverpool    Mohamed     Salah  Away        W 2–1        False

# %%
match_df["clean_sheet"].isna().sum()
# Out:
# np.int64(0)

# %%
match_df["primary_pos"] = match_df["pos"].str[0:2].astype("category")

# %%
match_df.head()
# Out:
#   season       team first_name last_name  match_date day_of_week  \
# 0  24/25  Liverpool    Mohamed     Salah  2024-08-25         Sun
# 1  24/25  Liverpool    Mohamed     Salah  2024-09-01         Sun
# 2  24/25  Liverpool    Mohamed     Salah  2024-09-14         Sat
# 3  24/25  Liverpool    Mohamed     Salah  2024-09-21         Sat
# 4  24/25  Liverpool    Mohamed     Salah  2024-09-28         Sat
#
#              comp        round venue match_result  ... goal_kicks_launch_pct  \
# 0  Premier League  Matchweek 2  Home        W 2–0  ...                   NaN
# 1  Premier League  Matchweek 3  Away        W 3–0  ...                   NaN
# 2  Premier League  Matchweek 4  Home        L 0–1  ...                   NaN
# 3  Premier League  Matchweek 5  Home        W 3–0  ...                   NaN
# 4  Premier League  Matchweek 6  Away        W 2–1  ...                   NaN
#
#   crosses_opp crosses_stp crosses_stp_pct sweeper_num_opa  sweeper_avgdist  \
# 0         NaN         NaN             NaN             NaN              NaN
# 1         NaN         NaN             NaN             NaN              NaN
# 2         NaN         NaN             NaN             NaN              NaN
# 3         NaN         NaN             NaN             NaN              NaN
# 4         NaN         NaN             NaN             NaN              NaN
#
#    opponent_prev_xg_per_game  opponent_prev_xga_per_game  clean_sheet  \
# 0                   1.531579                    1.473684        False
# 1                   1.486842                    1.813158         True
# 2                   1.313158                    1.400000         True
# 3                   1.471053                    1.528947        False
# 4                   1.228947                    1.781579        False
#
#    primary_pos
# 0           RW
# 1           RW
# 2           RW
# 3           RW
# 4           RW
#
# [5 rows x 69 columns]

# %%
match_df["venue"].unique()
# Out:
# array(['Home', 'Away'], dtype=object)

# %%
match_df["home"] = match_df["venue"] == "Home"

# %%
match_df.head()
# Out:
#   season       team first_name last_name  match_date day_of_week  \
# 0  24/25  Liverpool    Mohamed     Salah  2024-08-25         Sun
# 1  24/25  Liverpool    Mohamed     Salah  2024-09-01         Sun
# 2  24/25  Liverpool    Mohamed     Salah  2024-09-14         Sat
# 3  24/25  Liverpool    Mohamed     Salah  2024-09-21         Sat
# 4  24/25  Liverpool    Mohamed     Salah  2024-09-28         Sat
#
#              comp        round venue match_result  ... crosses_opp  \
# 0  Premier League  Matchweek 2  Home        W 2–0  ...         NaN
# 1  Premier League  Matchweek 3  Away        W 3–0  ...         NaN
# 2  Premier League  Matchweek 4  Home        L 0–1  ...         NaN
# 3  Premier League  Matchweek 5  Home        W 3–0  ...         NaN
# 4  Premier League  Matchweek 6  Away        W 2–1  ...         NaN
#
#   crosses_stp crosses_stp_pct sweeper_num_opa sweeper_avgdist  \
# 0         NaN             NaN             NaN             NaN
# 1         NaN             NaN             NaN             NaN
# 2         NaN             NaN             NaN             NaN
# 3         NaN             NaN             NaN             NaN
# 4         NaN             NaN             NaN             NaN
#
#    opponent_prev_xg_per_game  opponent_prev_xga_per_game  clean_sheet  \
# 0                   1.531579                    1.473684        False
# 1                   1.486842                    1.813158         True
# 2                   1.313158                    1.400000         True
# 3                   1.471053                    1.528947        False
# 4                   1.228947                    1.781579        False
#
#    primary_pos   home
# 0           RW   True
# 1           RW  False
# 2           RW   True
# 3           RW   True
# 4           RW  False
#
# [5 rows x 70 columns]

# %%
match_df["team"] = match_df["team"].astype("category")

# %%
match_df["player"] = match_df["first_name"] + ' ' + match_df["last_name"]

# %%
match_df.head()
# Out:
#   season       team first_name last_name  match_date day_of_week  \
# 0  24/25  Liverpool    Mohamed     Salah  2024-08-25         Sun
# 1  24/25  Liverpool    Mohamed     Salah  2024-09-01         Sun
# 2  24/25  Liverpool    Mohamed     Salah  2024-09-14         Sat
# 3  24/25  Liverpool    Mohamed     Salah  2024-09-21         Sat
# 4  24/25  Liverpool    Mohamed     Salah  2024-09-28         Sat
#
#              comp        round venue match_result  ... crosses_stp  \
# 0  Premier League  Matchweek 2  Home        W 2–0  ...         NaN
# 1  Premier League  Matchweek 3  Away        W 3–0  ...         NaN
# 2  Premier League  Matchweek 4  Home        L 0–1  ...         NaN
# 3  Premier League  Matchweek 5  Home        W 3–0  ...         NaN
# 4  Premier League  Matchweek 6  Away        W 2–1  ...         NaN
#
#   crosses_stp_pct sweeper_num_opa sweeper_avgdist opponent_prev_xg_per_game  \
# 0             NaN             NaN             NaN                  1.531579
# 1             NaN             NaN             NaN                  1.486842
# 2             NaN             NaN             NaN                  1.313158
# 3             NaN             NaN             NaN                  1.471053
# 4             NaN             NaN             NaN                  1.228947
#
#    opponent_prev_xga_per_game  clean_sheet  primary_pos   home         player
# 0                    1.473684        False           RW   True  Mohamed Salah
# 1                    1.813158         True           RW  False  Mohamed Salah
# 2                    1.400000         True           RW   True  Mohamed Salah
# 3                    1.528947        False           RW   True  Mohamed Salah
# 4                    1.781579        False           RW  False  Mohamed Salah
#
# [5 rows x 71 columns]

# %%
match_df["player"] = match_df["player"].astype("category")

# %%
seasons_sorted = list(match_df["season"].unique())
seasons_sorted.sort()
seasons_sorted
# Out:
# ['18/19', '19/20', '20/21', '21/22', '22/23', '23/24', '24/25']

# %%
match_df["season"] = match_df["season"].apply(lambda x: seasons_sorted.index(x))

# %%
match_df.head()
# Out:
#    season       team first_name last_name  match_date day_of_week  \
# 0       6  Liverpool    Mohamed     Salah  2024-08-25         Sun
# 1       6  Liverpool    Mohamed     Salah  2024-09-01         Sun
# 2       6  Liverpool    Mohamed     Salah  2024-09-14         Sat
# 3       6  Liverpool    Mohamed     Salah  2024-09-21         Sat
# 4       6  Liverpool    Mohamed     Salah  2024-09-28         Sat
#
#              comp        round venue match_result  ... crosses_stp  \
# 0  Premier League  Matchweek 2  Home        W 2–0  ...         NaN
# 1  Premier League  Matchweek 3  Away        W 3–0  ...         NaN
# 2  Premier League  Matchweek 4  Home        L 0–1  ...         NaN
# 3  Premier League  Matchweek 5  Home        W 3–0  ...         NaN
# 4  Premier League  Matchweek 6  Away        W 2–1  ...         NaN
#
#   crosses_stp_pct sweeper_num_opa sweeper_avgdist opponent_prev_xg_per_game  \
# 0             NaN             NaN             NaN                  1.531579
# 1             NaN             NaN             NaN                  1.486842
# 2             NaN             NaN             NaN                  1.313158
# 3             NaN             NaN             NaN                  1.471053
# 4             NaN             NaN             NaN                  1.228947
#
#    opponent_prev_xga_per_game  clean_sheet  primary_pos   home         player
# 0                    1.473684        False           RW   True  Mohamed Salah
# 1                    1.813158         True           RW  False  Mohamed Salah
# 2                    1.400000         True           RW   True  Mohamed Salah
# 3                    1.528947        False           RW   True  Mohamed Salah
# 4                    1.781579        False           RW  False  Mohamed Salah
#
# [5 rows x 71 columns]

# %%
match_df["time_idx"] = match_df["season"] * 38 + match_df["round"].str[len('Matchweek '):].astype(int)

# %%
match_df.head()
# Out:
#    season       team first_name last_name  match_date day_of_week  \
# 0       6  Liverpool    Mohamed     Salah  2024-08-25         Sun
# 1       6  Liverpool    Mohamed     Salah  2024-09-01         Sun
# 2       6  Liverpool    Mohamed     Salah  2024-09-14         Sat
# 3       6  Liverpool    Mohamed     Salah  2024-09-21         Sat
# 4       6  Liverpool    Mohamed     Salah  2024-09-28         Sat
#
#              comp        round venue match_result  ... crosses_stp_pct  \
# 0  Premier League  Matchweek 2  Home        W 2–0  ...             NaN
# 1  Premier League  Matchweek 3  Away        W 3–0  ...             NaN
# 2  Premier League  Matchweek 4  Home        L 0–1  ...             NaN
# 3  Premier League  Matchweek 5  Home        W 3–0  ...             NaN
# 4  Premier League  Matchweek 6  Away        W 2–1  ...             NaN
#
#   sweeper_num_opa sweeper_avgdist opponent_prev_xg_per_game  \
# 0             NaN             NaN                  1.531579
# 1             NaN             NaN                  1.486842
# 2             NaN             NaN                  1.313158
# 3             NaN             NaN                  1.471053
# 4             NaN             NaN                  1.228947
#
#   opponent_prev_xga_per_game  clean_sheet  primary_pos   home         player  \
# 0                   1.473684        False           RW   True  Mohamed Salah
# 1                   1.813158         True           RW  False  Mohamed Salah
# 2                   1.400000         True           RW   True  Mohamed Salah
# 3                   1.528947        False           RW   True  Mohamed Salah
# 4                   1.781579        False           RW  False  Mohamed Salah
#
#    time_idx
# 0       230
# 1       231
# 2       232
# 3       233
# 4       234
#
# [5 rows x 72 columns]

# %%
match_df["did_player_start"].unique()
# Out:
# array(['Y', 'Y*', 'N'], dtype=object)

# %%
match_df["did_player_start"] = match_df["did_player_start"].apply(lambda x: 'Y' in x)

# %%
match_df[["team", "player", "match_date", "played_minutes", "did_player_start"]].head()
# Out:
#         team         player  match_date played_minutes  did_player_start
# 0  Liverpool  Mohamed Salah  2024-08-25             82              True
# 1  Liverpool  Mohamed Salah  2024-09-01             90              True
# 2  Liverpool  Mohamed Salah  2024-09-14             90              True
# 3  Liverpool  Mohamed Salah  2024-09-21             90              True
# 4  Liverpool  Mohamed Salah  2024-09-28             90              True

# %%
match_df[["team", "player", "match_date", "played_minutes", "did_player_start"]].loc[match_df["did_player_start"] == False].head()
# Out:
#           team               player  match_date played_minutes  \
# 100  Liverpool  Alexis Mac Allister  2024-10-20             10
# 121  Liverpool  Alexis Mac Allister  2025-05-04             22
# 122  Liverpool  Alexis Mac Allister  2025-05-11             24
# 154  Liverpool   Dominik Szoboszlai  2024-10-05             45
# 156  Liverpool   Dominik Szoboszlai  2024-10-27             28
#
#      did_player_start
# 100             False
# 121             False
# 122             False
# 154             False
# 156             False

# %%
#TODO fill missing matches with 0s?
